# %% [markdown]
# https://top2vec.readthedocs.io/en/latest/Top2Vec.html#

# %%
import pandas as pd
import numpy as np
import math
from top2vec import Top2Vec
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/data.csv')
data.head()
# Out:
#    FidelityLevel                                             Phrase
# 0  High fidelity  important the relationship between mental and ...
# 1  High fidelity  problems with their physical health and psycho...
# 2  High fidelity                          stress impacts our health
# 3  High fidelity  understand how mental and physical health cond...
# 4  High fidelity                     get what you want out of life.

# %%
text_list = list(data['Phrase'])

# %%
model = Top2Vec(text_list)
# Out:
# 2022-05-08 14:25:08,332 - top2vec - INFO - Pre-processing documents for training
# 2022-05-08 14:25:08,373 - top2vec - INFO - Creating joint document/word embedding
# 2022-05-08 14:25:10,135 - top2vec - INFO - Creating lower dimension embedding of documents
# 2022-05-08 14:25:20,571 - top2vec - INFO - Finding dense areas of documents
# 2022-05-08 14:25:20,638 - top2vec - INFO - Finding topics

# %%
 model.get_num_topics()
# Out:
# 2

# %%
topic_sizes, topic_nums = model.get_topic_sizes()

# %%
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)

# %%
data_high = data.loc[(data['FidelityLevel'] == 'High fidelity')]

# %%
data_high.shape
# Out:
# (1261, 2)

# %%
text_list = list(data_high['Phrase'])
model = Top2Vec(text_list)
model.get_num_topics()
# Out:
# 2022-05-08 14:28:51,896 - top2vec - INFO - Pre-processing documents for training
# 2022-05-08 14:28:51,924 - top2vec - INFO - Creating joint document/word embedding
# 2022-05-08 14:28:53,137 - top2vec - INFO - Creating lower dimension embedding of documents
# 2022-05-08 14:28:57,371 - top2vec - INFO - Finding dense areas of documents
# 2022-05-08 14:28:57,414 - top2vec - INFO - Finding topics
# 3

# %%
topic_sizes, topic_nums = model.get_topic_sizes()
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)

# %%
data_low = data.loc[(data['FidelityLevel'] == 'Low fidelity')]

# %%
text_list = list(data_low['Phrase'])
model = Top2Vec(text_list)
model.get_num_topics()
# Out:
# 2022-05-08 14:29:15,489 - top2vec - INFO - Pre-processing documents for training
# 2022-05-08 14:29:15,501 - top2vec - INFO - Creating joint document/word embedding
# 2022-05-08 14:29:16,222 - top2vec - INFO - Creating lower dimension embedding of documents
# 2022-05-08 14:29:18,778 - top2vec - INFO - Finding dense areas of documents
# 2022-05-08 14:29:18,792 - top2vec - INFO - Finding topics
# 2

# %%
topic_sizes, topic_nums = model.get_topic_sizes()
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)
